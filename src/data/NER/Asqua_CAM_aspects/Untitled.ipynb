# %%
import random
import numpy as np
import pandas as pd
train_df = pd.DataFrame(columns = ['word', 'tag'])
dev_df = pd.DataFrame(columns = ['word', 'tag'])
test_df = pd.DataFrame(columns = ['word', 'tag'])

# %%
import pandas as pd
train = pd.read_csv("CAM_train.csv", names = ['word', 'tag'])
test = pd.read_csv("CAM_dev.csv", names = ['word', 'tag'])
dev = pd.read_csv("CAM_test.csv",  names = ['word', 'tag'])

# %%
train
# Out:
#               word       tag
# 0              1tb         O
# 1               of         O
# 2       mechanical         O
# 3          storage         O
# 4               is         O
# 5              n't         O
# 6              bad         O
# 7                ,         O
# 8              but         O
# 9          toshiba  B-OTHOBJ
# 10            hard         O
# 11          drives         O
# 12          really         O
# 13             are         O
# 14             n't         O
# 15            what         O
# 16              we         O
# 17            want         O
# 18              to         O
# 19              be         O
# 20          seeing         O
# 21              as         O
# 22            they         O
# 23            tend         O
# 24              to         O
# 25              be         O
# 26               a         O
# 27             bit         O
# 28          slower         O
# 29            than         O
# ...            ...       ...
# ...

# %%
train.to_csv('CAM_train.csv', header=False, index=False, sep = '\t')
dev.to_csv('CAM_dev.csv', index=False, header=False, sep = '\t')
test.to_csv('CAM_test.csv', header=False, index=False, sep = '\t')

# %%
train1 = pd.read_csv("CAM_train.csv", names = ['word', 'tag'], sep = '\t')
train1
# Out:
#               word       tag
# 0              1tb         O
# 1               of         O
# 2       mechanical         O
# 3          storage         O
# 4               is         O
# 5              n't         O
# 6              bad         O
# 7                ,         O
# 8              but         O
# 9          toshiba  B-OTHOBJ
# 10            hard         O
# 11          drives         O
# 12          really         O
# 13             are         O
# 14             n't         O
# 15            what         O
# 16              we         O
# 17            want         O
# 18              to         O
# 19              be         O
# 20          seeing         O
# 21              as         O
# 22            they         O
# 23            tend         O
# 24              to         O
# 25              be         O
# 26               a         O
# 27             bit         O
# 28          slower         O
# 29            than         O
# ...            ...       ...
# ...
